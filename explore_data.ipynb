# %%
# !ls
# Out:
# README.md   data		preprocessing
# clap-to-t5  explore_data.ipynb	requirements.txt

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
from google.cloud import storage

# %%
# Check if GPU is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class AudioToTextModel(nn.Module):
    def __init__(self):
        super(AudioToTextModel, self).__init__()
        # Initialize T5 model and tokenizer
        self.t5 = T5ForConditionalGeneration.from_pretrained("t5-small")
        self.tokenizer = T5Tokenizer.from_pretrained("t5-small")

    def forward(self, audio_embeddings, labels=None):
        # Ensure correct shape for inputs_embeds: (batch_size, seq_length, embedding_dim)
        # T5 expects the shape (batch_size, seq_length, embedding_dim)
        projected_embeddings = audio_embeddings.unsqueeze(1)  # Add seq_length dimension (usually 1 for this case)

        # Generate outputs with T5
        outputs = self.t5(
            inputs_embeds=projected_embeddings,
            labels=labels
        )
        return outputs

# %%
model = AudioToTextModel()
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
model.load_state_dict(torch.load('data/trained_audio_to_text_model.pth'))

# Step 4: Set the model to evaluation mode (if you only need to do inference)
model.eval()
# Out:
# /var/tmp/ipykernel_6536/1328369586.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('data/trained_audio_to_text_model.pth'))
# AudioToTextModel(
#   (t5): T5ForConditionalGeneration(
#     (shared): Embedding(32128, 512)
#     (encoder): T5Stack(
#       (embed_tokens): Embedding(32128, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoder): T5Stack(
#       (embed_tokens): Embedding(32128, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (lm_head): Linear(in_features=512, out_features=32128, bias=False)
#   )
# )

# %%
model = model.to(device)

# %%
# Load the training data
train_data = torch.load('data/train_data.pt')
# Out:
# /var/tmp/ipykernel_6536/471029577.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_data = torch.load('data/train_data.pt')

# %%
train_embeddings = torch.tensor(np.array(train_data["embeddings"])).to(device)  # Move to GPU
train_labels = [str(label) for label in train_data["labels"]]

# %%
train_embeddings[0].size()
# Out:
# torch.Size([512])

# %%
train_embeddings[:2].device
# Out:
# device(type='cuda', index=0)

# %%
inputs_embeds = train_embeddings[0].unsqueeze(1).unsqueeze(1)  # Shape becomes (2, 1, 512)
inputs_embeds.size()
# Out:
# torch.Size([512, 1, 1])

# %%
# Ensure train_embeddings has the correct shape (batch_size, seq_length, embedding_dim)


# Run inference using generate()
with torch.no_grad():
    generated_ids = model.t5.generate(
        inputs_embeds=inputs_embeds,
        max_length=50,  # Adjust as needed
        num_beams=2,    # Optional: for beam search
        early_stopping=True
    )

# Decode the generated token IDs to text
for i, gen_id in enumerate(generated_ids):
    decoded_text = tokenizer.decode(gen_id, skip_special_tokens=False)
    print(f"Generated text {i+1}: {decoded_text}")
# Out:
# Generated text 1: <pad>
# Generated text 2: <pad>
# Generated text 3: <pad>
# Generated text 4: <pad>
# Generated text 5: <pad>
# Generated text 6: <pad>
# Generated text 7: <pad>
# Generated text 8: <pad>
# Generated text 9: <pad>
# Generated text 10: <pad>
# Generated text 11: <pad>
# Generated text 12: <pad>
# Generated text 13: <pad>
# Generated text 14: <pad>
# Generated text 15: <pad>
# Generated text 16: <pad>
# Generated text 17: <pad>
# Generated text 18: <pad>
# Generated text 19: <pad>
# Generated text 20: <pad>
# Generated text 21: <pad>
# Generated text 22: <pad>
# Generated text 23: <pad>
# Generated text 24: <pad>
# Generated text 25: <pad>
# Generated text 26: <pad>
# Generated text 27: <pad>
# Generated text 28: <pad>
# Generated text 29: <pad>
# Generated text 30: <pad>
# Generated text 31: <pad>
# Generated text 32: <pad>
# Generated text 33: <pad>
# Generated text 34: <pad>
# Generated text 35: <pad>
# Generated text 36: <pad>
# Generated text 37: <pad>
# Generated text 38: <pad>
# Generated text 39: <pad>
# Generated text 40: <pad>
# Generated text 41: <pad>
# Generated text 42: <pad>
# Generated text 43: <pad>
# Generated text 44: <pad>
# Generated text 45: <pad>
# Generated text 46: <pad>
# Generated text 47: <pad>
# Generated text 48: <pad>
# Generated text 49: <pad>
# Generated text 50: <pad>
# Generated text 51: <pad>
# Generated text 52: <pad>
# Generated text 53: <pad>
# Generated text 54: <pad>
# Generated text 55: <pad>
# Generated text 56: <pad>
# Generated text 57: <pad>
# Generated text 58: <pad>
# Generated text 59: <pad>
# Generated text 60: <pad>
# Generated text 61: <pad>
# Generated text 62: <pad>
# Generated text 63: <pad>
# Generated text 64: <pad>
# Generated text 65: <pad>
# Generated text 66: <pad>
# Generated text 67: <pad>
# Generated text 68: <pad>
# Generated text 69: <pad>
# Generated text 70: <pad>
# Generated text 71: <pad>
# Generated text 72: <pad>
# Generated text 73: <pad>
# Generated text 74: <pad>
# Generated text 75: <pad>
# Generated text 76: <pad>
# Generated text 77: <pad>
# Generated text 78: <pad>
# Generated text 79: <pad>
# Generated text 80: <pad>
# Generated text 81: <pad>
# Generated text 82: <pad>
# Generated text 83: <pad>
# Generated text 84: <pad>
# Generated text 85: <pad>
# Generated text 86: <pad>
# Generated text 87: <pad>
# Generated text 88: <pad>
# Generated text 89: <pad>
# Generated text 90: <pad>
# Generated text 91: <pad>
# Generated text 92: <pad>
# Generated text 93: <pad>
# Generated text 94: <pad>
# Generated text 95: <pad>
# Generated text 96: <pad>
# Generated text 97: <pad>
# Generated text 98: <pad>
# Generated text 99: <pad>
# Generated text 100: <pad>
# Generated text 101: <pad>
# Generated text 102: <pad>
# Generated text 103: <pad>
# Generated text 104: <pad>
# Generated text 105: <pad>
# Generated text 106: <pad>
# Generated text 107: <pad>
# Generated text 108: <pad>
# Generated text 109: <pad>
# Generated text 110: <pad>
# Generated text 111: <pad>
# Generated text 112: <pad>
# Generated text 113: <pad>
# Generated text 114: <pad>
# Generated text 115: <pad>
# Generated text 116: <pad>
# Generated text 117: <pad>
# Generated text 118: <pad>
# Generated text 119: <pad>
# Generated text 120: <pad>
# Generated text 121: <pad>
# Generated text 122: <pad>
# Generated text 123: <pad>
# Generated text 124: <pad>
# Generated text 125: <pad>
# Generated text 126: <pad>
# Generated text 127: <pad>
# Generated text 128: <pad>
# Generated text 129: <pad>
# Generated text 130: <pad>
# Generated text 131: <pad>
# Generated text 132: <pad>
# Generated text 133: <pad>
# Generated text 134: <pad>
# Generated text 135: <pad>
# Generated text 136: <pad>
# Generated text 137: <pad>
# Generated text 138: <pad>
# Generated text 139: <pad>
# Generated text 140: <pad>
# Generated text 141: <pad>
# Generated text 142: <pad>
# Generated text 143: <pad>
# Generated text 144: <pad>
# Generated text 145: <pad>
# Generated text 146: <pad>
# Generated text 147: <pad>
# Generated text 148: <pad>
# Generated text 149: <pad>
# Generated text 150: <pad>
# Generated text 151: <pad>
# Generated text 152: <pad>
# Generated text 153: <pad>
# Generated text 154: <pad>
# Generated text 155: <pad>
# Generated text 156: <pad>
# Generated text 157: <pad>
# Generated text 158: <pad>
# Generated text 159: <pad>
# Generated text 160: <pad>
# Generated text 161: <pad>
# Generated text 162: <pad>
# Generated text 163: <pad>
# Generated text 164: <pad>
# Generated text 165: <pad>
# Generated text 166: <pad>
# Generated text 167: <pad>
# Generated text 168: <pad>
# Generated text 169: <pad>
# Generated text 170: <pad>
# Generated text 171: <pad>
# Generated text 172: <pad>
# Generated text 173: <pad>
# Generated text 174: <pad>
# Generated text 175: <pad>
# Generated text 176: <pad>
# Generated text 177: <pad>
# Generated text 178: <pad>
# Generated text 179: <pad>
# Generated text 180: <pad>
# Generated text 181: <pad>
# Generated text 182: <pad>
# Generated text 183: <pad>
# Generated text 184: <pad>
# Generated text 185: <pad>
# Generated text 186: <pad>
# Generated text 187: <pad>
# Generated text 188: <pad>
# Generated text 189: <pad>
# Generated text 190: <pad>
# Generated text 191: <pad>
# Generated text 192: <pad>
# Generated text 193: <pad>
# Generated text 194: <pad>
# Generated text 195: <pad>
# Generated text 196: <pad>
# Generated text 197: <pad>
# Generated text 198: <pad>
# Generated text 199: <pad>
# Generated text 200: <pad>
# Generated text 201: <pad>
# Generated text 202: <pad>
# Generated text 203: <pad>
# Generated text 204: <pad>
# Generated text 205: <pad>
# Generated text 206: <pad>
# Generated text 207: <pad>
# Generated text 208: <pad>
# Generated text 209: <pad>
# Generated text 210: <pad>
# Generated text 211: <pad>
# Generated text 212: <pad>
# Generated text 213: <pad>
# Generated text 214: <pad>
# Generated text 215: <pad>
# Generated text 216: <pad>
# Generated text 217: <pad>
# Generated text 218: <pad>
# Generated text 219: <pad>
# Generated text 220: <pad>
# Generated text 221: <pad>
# Generated text 222: <pad>
# Generated text 223: <pad>
# Generated text 224: <pad>
# Generated text 225: <pad>
# Generated text 226: <pad>
# Generated text 227: <pad>
# Generated text 228: <pad>
# Generated text 229: <pad>
# Generated text 230: <pad>
# Generated text 231: <pad>
# Generated text 232: <pad>
# Generated text 233: <pad>
# Generated text 234: <pad>
# Generated text 235: <pad>
# Generated text 236: <pad>
# Generated text 237: <pad>
# Generated text 238: <pad>
# Generated text 239: <pad>
# Generated text 240: <pad>
# Generated text 241: <pad>
# Generated text 242: <pad>
# Generated text 243: <pad>
# Generated text 244: <pad>
# Generated text 245: <pad>
# Generated text 246: <pad>
# Generated text 247: <pad>
# Generated text 248: <pad>
# Generated text 249: <pad>
# Generated text 250: <pad>
# Generated text 251: <pad>
# Generated text 252: <pad>
# Generated text 253: <pad>
# Generated text 254: <pad>
# Generated text 255: <pad>
# Generated text 256: <pad>
# Generated text 257: <pad>
# Generated text 258: <pad>
# Generated text 259: <pad>
# Generated text 260: <pad>
# Generated text 261: <pad>
# Generated text 262: <pad>
# Generated text 263: <pad>
# Generated text 264: <pad>
# Generated text 265: <pad>
# Generated text 266: <pad>
# Generated text 267: <pad>
# Generated text 268: <pad>
# Generated text 269: <pad>
# Generated text 270: <pad>
# Generated text 271: <pad>
# Generated text 272: <pad>
# Generated text 273: <pad>
# Generated text 274: <pad>
# Generated text 275: <pad>
# Generated text 276: <pad>
# Generated text 277: <pad>
# Generated text 278: <pad>
# Generated text 279: <pad>
# Generated text 280: <pad>
# Generated text 281: <pad>
# Generated text 282: <pad>
# Generated text 283: <pad>
# Generated text 284: <pad>
# Generated text 285: <pad>
# Generated text 286: <pad>
# Generated text 287: <pad>
# Generated text 288: <pad>
# Generated text 289: <pad>
# Generated text 290: <pad>
# Generated text 291: <pad>
# Generated text 292: <pad>
# Generated text 293: <pad>
# Generated text 294: <pad>
# Generated text 295: <pad>
# Generated text 296: <pad>
# Generated text 297: <pad>
# Generated text 298: <pad>
# Generated text 299: <pad>
# Generated text 300: <pad>
# Generated text 301: <pad>
# Generated text 302: <pad>
# Generated text 303: <pad>
# Generated text 304: <pad>
# Generated text 305: <pad>
# Generated text 306: <pad>
# Generated text 307: <pad>
# Generated text 308: <pad>
# Generated text 309: <pad>
# Generated text 310: <pad>
# Generated text 311: <pad>
# Generated text 312: <pad>
# Generated text 313: <pad>
# Generated text 314: <pad>
# Generated text 315: <pad>
# Generated text 316: <pad>
# Generated text 317: <pad>
# Generated text 318: <pad>
# Generated text 319: <pad>
# Generated text 320: <pad>
# Generated text 321: <pad>
# Generated text 322: <pad>
# Generated text 323: <pad>
# Generated text 324: <pad>
# Generated text 325: <pad>
# Generated text 326: <pad>
# Generated text 327: <pad>
# Generated text 328: <pad>
# Generated text 329: <pad>
# Generated text 330: <pad>
# Generated text 331: <pad>
# Generated text 332: <pad>
# Generated text 333: <pad>
# Generated text 334: <pad>
# Generated text 335: <pad>
# Generated text 336: <pad>
# Generated text 337: <pad>
# Generated text 338: <pad>
# Generated text 339: <pad>
# Generated text 340: <pad>
# Generated text 341: <pad>
# Generated text 342: <pad>
# Generated text 343: <pad>
# Generated text 344: <pad>
# Generated text 345: <pad>
# Generated text 346: <pad>
# Generated text 347: <pad>
# Generated text 348: <pad>
# Generated text 349: <pad>
# Generated text 350: <pad>
# Generated text 351: <pad>
# Generated text 352: <pad>
# Generated text 353: <pad>
# Generated text 354: <pad>
# Generated text 355: <pad>
# Generated text 356: <pad>
# Generated text 357: <pad>
# Generated text 358: <pad>
# Generated text 359: <pad>
# Generated text 360: <pad>
# Generated text 361: <pad>
# Generated text 362: <pad>
# Generated text 363: <pad>
# Generated text 364: <pad>
# Generated text 365: <pad>
# Generated text 366: <pad>
# Generated text 367: <pad>
# Generated text 368: <pad>
# Generated text 369: <pad>
# Generated text 370: <pad>
# Generated text 371: <pad>
# Generated text 372: <pad>
# Generated text 373: <pad>
# Generated text 374: <pad>
# Generated text 375: <pad>
# Generated text 376: <pad>
# Generated text 377: <pad>
# Generated text 378: <pad>
# Generated text 379: <pad>
# Generated text 380: <pad>
# Generated text 381: <pad>
# Generated text 382: <pad>
# Generated text 383: <pad>
# Generated text 384: <pad>
# Generated text 385: <pad>
# Generated text 386: <pad>
# Generated text 387: <pad>
# Generated text 388: <pad>
# Generated text 389: <pad>
# Generated text 390: <pad>
# Generated text 391: <pad>
# Generated text 392: <pad>
# Generated text 393: <pad>
# Generated text 394: <pad>
# Generated text 395: <pad>
# Generated text 396: <pad>
# Generated text 397: <pad>
# Generated text 398: <pad>
# Generated text 399: <pad>
# Generated text 400: <pad>
# Generated text 401: <pad>
# Generated text 402: <pad>
# Generated text 403: <pad>
# Generated text 404: <pad>
# Generated text 405: <pad>
# Generated text 406: <pad>
# Generated text 407: <pad>
# Generated text 408: <pad>
# Generated text 409: <pad>
# Generated text 410: <pad>
# Generated text 411: <pad>
# Generated text 412: <pad>
# Generated text 413: <pad>
# Generated text 414: <pad>
# Generated text 415: <pad>
# Generated text 416: <pad>
# Generated text 417: <pad>
# Generated text 418: <pad>
# Generated text 419: <pad>
# Generated text 420: <pad>
# Generated text 421: <pad>
# Generated text 422: <pad>
# Generated text 423: <pad>
# Generated text 424: <pad>
# Generated text 425: <pad>
# Generated text 426: <pad>
# Generated text 427: <pad>
# Generated text 428: <pad>
# Generated text 429: <pad>
# Generated text 430: <pad>
# Generated text 431: <pad>
# Generated text 432: <pad>
# Generated text 433: <pad>
# Generated text 434: <pad>
# Generated text 435: <pad>
# Generated text 436: <pad>
# Generated text 437: <pad>
# Generated text 438: <pad>
# Generated text 439: <pad>
# Generated text 440: <pad>
# Generated text 441: <pad>
# Generated text 442: <pad>
# Generated text 443: <pad>
# Generated text 444: <pad>
# Generated text 445: <pad>
# Generated text 446: <pad>
# Generated text 447: <pad>
# Generated text 448: <pad>
# Generated text 449: <pad>
# Generated text 450: <pad>
# Generated text 451: <pad>
# Generated text 452: <pad>
# Generated text 453: <pad>
# Generated text 454: <pad>
# Generated text 455: <pad>
# Generated text 456: <pad>
# Generated text 457: <pad>
# Generated text 458: <pad>
# Generated text 459: <pad>
# Generated text 460: <pad>
# Generated text 461: <pad>
# Generated text 462: <pad>
# Generated text 463: <pad>
# Generated text 464: <pad>
# Generated text 465: <pad>
# Generated text 466: <pad>
# Generated text 467: <pad>
# Generated text 468: <pad>
# Generated text 469: <pad>
# Generated text 470: <pad>
# Generated text 471: <pad>
# Generated text 472: <pad>
# Generated text 473: <pad>
# Generated text 474: <pad>
# Generated text 475: <pad>
# Generated text 476: <pad>
# Generated text 477: <pad>
# Generated text 478: <pad>
# Generated text 479: <pad>
# Generated text 480: <pad>
# Generated text 481: <pad>
# Generated text 482: <pad>
# Generated text 483: <pad>
# Generated text 484: <pad>
# Generated text 485: <pad>
# Generated text 486: <pad>
# Generated text 487: <pad>
# Generated text 488: <pad>
# Generated text 489: <pad>
# Generated text 490: <pad>
# Generated text 491: <pad>
# Generated text 492: <pad>
# Generated text 493: <pad>
# Generated text 494: <pad>
# Generated text 495: <pad>
# Generated text 496: <pad>
# Generated text 497: <pad>
# Generated text 498: <pad>
# Generated text 499: <pad>
# Generated text 500: <pad>
# Generated text 501: <pad>
# Generated text 502: <pad>
# Generated text 503: <pad>
# Generated text 504: <pad>
# Generated text 505: <pad>
# Generated text 506: <pad>
# Generated text 507: <pad>
# Generated text 508: <pad>
# Generated text 509: <pad>
# Generated text 510: <pad>
# Generated text 511: <pad>
# Generated text 512: <pad>
