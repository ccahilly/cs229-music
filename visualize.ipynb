# %%
import numpy as np

data = {
    "mert_frozen_losses": [219.5174, 197.7317, 180.2569, 167.6247, 156.1796, 147.2849, 138.5859, 131.2512, 124.8657, 118.7091],
    "mert_unfrozen_losses": [193.6782, 115.9593, 73.9087, 46.9252, 29.0631, 17.5015, 10.7113, 7.0529, 5.0213, 3.7179],
    "clap_frozen_losses": [224.3057, 209.9845, 202.4767, 197.2513, 193.0246, 189.5330, 185.9289, 183.6792, 181.155, 178.8226],
    "clap_unfrozen_losses": [208.1432, 189.9145, 176.3889, 165.2718, 154.7832, 144.3195, 133.9622, 123.4433, 112.7856, 102.8297],
    "wav2vec_frozen_losses": [225.9406, 204.9075, 190.1826, 180.1907, 172.4147, 166.2427, 159.0053, 154.195, 150.1985, 147.3652],
    "wav2vec_unfrozen_losses": [200.2984, 155.9033, 129.7606, 109.8650, 93.1333, 76.0114, 64.5011, 48.2726, 39.0806, 33.6791],
}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
for key, values in data.items():
    plt.plot(values, label=key.replace('_', ' ').title())

# Formatting
plt.title("Loss Curves for Different Models and Configurations", fontsize=14)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.legend(loc="upper right", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
